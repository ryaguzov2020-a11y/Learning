# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

y = np.random.normal(0, 2, 500)

ax.hist(y, 50)

ax.grid()

plt.show()

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

y = np.random.normal(0, 2, 500)

ax.hist(y, 50)

ax.grid()

plt.show()

# %% [markdown]
# ## Функции bar() и barh()
# Похожий график можно сформировать и с помощью функции bar. Ей на вход, в самом простом варианте, нужно передать список отметок для столбцов x и значения высот каждого столбца y:
#
# bar(x, y)

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

x = [f'H{i+1}' for i in range(10)]
y = np.random.randint(1, 5, len(x))
ax.bar(x, y)

ax.grid()

plt.show()

# %% [markdown]
# Если нам нужно отображать столбики относительно оси ординат, то для этого существует функция barh(), которая работает аналогично функции bar():

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

x = [f'H{i+1}' for i in range(10)]
y = np.random.randint(1, 5, len(x))
ax.barh(x, y)

ax.grid()

plt.show()

# %% [markdown]
# ![image.png](attachment:bd4b6ed2-f02f-49bd-91da-70f83112ae6f.png)

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

x = np.arange(10)
y1 = np.random.randint(3, 20, len(x))
y2 = np.random.randint(3, 20, len(x))
w = 0.3
ax.bar(x - w/2, y1, width=w)
ax.bar(x + w/2, y2, width=w)

ax.grid()

plt.show()

# %% [markdown]
# ## Круговые диаграммы
# Иногда вместо столбцов нам нужно наглядно изобразить доли чего-либо в виде круговой диаграммы. Для этого используется функция pie(), например, следующим образом:

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

values = [10, 40, 23, 30, 7]
labels = ['Toyota', 'BMW', 'Lexus', 'Audi', 'Lada']
ax.pie(values, labels=labels)

ax.grid()

plt.show()

# %% [markdown]
# ![image.png](attachment:869b0c7d-bfdf-4932-8d58-8f6de9fb18ee.png)

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

values = [10, 40, 23, 30, 7]
labels = ['Toyota', 'BMW', 'Lexus', 'Audi', 'Lada']
exp = (0.1, 0.2, 0, 0, 0)
ax.pie(values, labels=labels, autopct='%.2f', explode=exp, shadow=True)

ax.grid()

plt.show()

# %%
fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot()

values = [10, 40, 23, 30, 7]
labels = ['Toyota', 'BMW', 'Lexus', 'Audi', 'Lada']
ax.pie(values, labels=labels, autopct='%.2f', wedgeprops=dict(width=0.5), shadow=False)

ax.grid()

plt.show()
