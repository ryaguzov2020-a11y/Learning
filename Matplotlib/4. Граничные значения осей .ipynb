# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ax.set(xlim=(xmin, xmax), ylim=(ymin, ymax))

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()
ax.plot(np.arange(1, 5, 0.25))
ax.set(xlim=(-5, 30), ylim=(-1, 6))

plt.show()

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()
ax.plot(np.arange(1, 5, 0.25))
ax.set_xlim(xmin=-5, xmax=20)
ax.set_ylim(ymin=-1, ymax=8)
plt.show()

# %% [markdown]
# ## Положение меток на координатных осях

# %% [markdown]
# set_major_locator() – управление рисками крупной сетки;
# set_minor_locator() – управление рисками мелкой сетки.

# %% [markdown]
# ## NullLocator
# Давайте воспользуемся самым простым производным классом NullLocator,
# который используется для сокрытия меток по выбранной оси.

# %%
from matplotlib.ticker import NullLocator, LinearLocator

# %%
lc = NullLocator()

fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()
ax.plot(np.arange(1, 5, 0.25))

ax.grid()
ax.yaxis.set_major_locator(lc)

plt.show()

# %% [markdown]
# ## LinearLocator
# Используется для задания нужного числа меток по выбранной оси графика.
# Например, вот так можно задать ровно пять рисок по оси Oy:

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()
ax.plot(np.arange(1, 5, 0.25))

ax.grid()
ax.yaxis.set_major_locator(LinearLocator(5))

plt.show()

# %% [markdown]
# ## MultipleLocator
# Следующий класс MultipleLocator позволяет задавать шаг изменения значений между соседними рисками. Для этого используется единственный параметр base этого класса, который и определяет шаг следования значений

# %%
from matplotlib.ticker import MultipleLocator

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()
ax.plot(np.arange(1, 5, 0.25))

ax.grid()
ax.xaxis.set_major_locator(MultipleLocator(base=1))

plt.show()

# %% [markdown]
# ## IndexLocator
# Следующий класс IndexLocator работает аналогичным образом, что и класс MultipleLocator, но производит отсчет значений рисок не от 0, а от наименьшего значения данных графика. В конструкторе класса IndexLocator определены два параметра:
#
# base – шаг изменения между соседними рисками;
# offset – смещение относительно наименьшего значения.

# %%
from matplotlib.ticker import IndexLocator

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

x = np.arange(-np.pi/2, np.pi, 0.1)
ax.plot(x, np.sin(x))

ax.grid()
ax.xaxis.set_major_locator(IndexLocator(base=0.5, offset=0))

plt.show()

# %% [markdown]
# ## FixedLocator
# Это очень простой класс локатора, который устанавливает метки в указанных значениях. Например, так:

# %%
from matplotlib.ticker import FixedLocator

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

x = np.arange(-np.pi/2, np.pi, 0.1)
ax.plot(x, np.sin(x))

ax.grid()
ax.xaxis.set_major_locator(FixedLocator([-2, -1, 0, 1, 2, 3]))

plt.show()

# %% [markdown]
# ## MaxNLocator
# Следующий локатор выполняет самостоятельную разбивку интервала на число рисок не более значения nbins, указанного при создании его экземпляра. В самом простом варианте мы можем создать объект этого локатора без указания максимального числа рисок:

# %%
from matplotlib.ticker import MaxNLocator

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

x = np.arange(-np.pi/2, np.pi, 0.1)
ax.plot(x, np.sin(x))

ax.grid()
ax.xaxis.set_major_locator(MaxNLocator())

plt.show()

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

x = np.arange(-np.pi/2, np.pi, 0.1)
ax.plot(x, np.sin(x))

ax.grid()
ax.xaxis.set_major_locator(MaxNLocator(nbins=5))

plt.show()

# %% [markdown]
# Локатор создал разбиение с четырьмя рисками. То есть, он решил, что такое разбиение будет наиболее понятным, т.к. значения рисок принимают «красивые» значения и с ними будет легко работать конечному пользователю. В общем, в этом и заключается цель этого локатора

# %% [markdown]
# ## Использование функции set_minor_locator()
# Все те же самые действия можно выполнять и с мелкой (минорной) сеткой. Для этого ее нужно сначала включить и показать на графике:

# %%
fig = plt.figure(figsize=(7, 4))
ax = fig.add_subplot()

x = np.arange(-np.pi/2, np.pi, 0.1)
ax.plot(x, np.sin(x))

ax.minorticks_on()
ax.grid(which='major', lw = 2) 
ax.grid(which='minor')

ax.xaxis.set_minor_locator(NullLocator())

plt.show()
