# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([[1, 2, 3],
                   [4, 5, 6],
                   [7, 8, 9],
                   [np.nan, np.nan, np.nan]],
                 columns = ['col_1', 'col_2', 'col_3']
                 )

df
# Out:
#    col_1  col_2  col_3
# 0    1.0    2.0    3.0
# 1    4.0    5.0    6.0
# 2    7.0    8.0    9.0
# 3    NaN    NaN    NaN

# %% [markdown]
# ![image.png](attachment:ad741772-bf72-40b3-88f2-b07d1dd8b3f8.png)

# %%
df.min()
# Out:
# col_1    1.0
# col_2    2.0
# col_3    3.0
# dtype: float64

# %%
df.mean()
# Out:
# col_1    4.0
# col_2    5.0
# col_3    6.0
# dtype: float64

# %%
df.count()
# Out:
# col_1    3
# col_2    3
# col_3    3
# dtype: int64

# %%
df['col_3'].sum()
# Out:
# 18.0

# %%
df.agg('mean')
# Out:
# col_1    4.0
# col_2    5.0
# col_3    6.0
# dtype: float64

# %%
df.agg( ['max', 'min', 'sum', 'mean'] )
# Out:
#       col_1  col_2  col_3
# max     7.0    8.0    9.0
# min     1.0    2.0    3.0
# sum    12.0   15.0   18.0
# mean    4.0    5.0    6.0

# %%
df.agg('max', axis = 1)
# Out:
# 0    3.0
# 1    6.0
# 2    9.0
# 3    NaN
# dtype: float64

# %%
df['col_3'].agg( ['min', 'max', 'mean'] )
# Out:
# min     3.0
# max     9.0
# mean    6.0
# Name: col_3, dtype: float64

# %%
df.agg( {'col_1': ['min', 'sum'],
         'col_3': 'mean'}
      )
# Out:
#       col_1  col_3
# min     1.0    NaN
# sum    12.0    NaN
# mean    NaN    6.0
