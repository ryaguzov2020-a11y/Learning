# %%
import numpy as np
import pandas as pd

# %%
df_date = pd.read_excel('datefor19.xlsx')

df_date
# Out:
#        id       date
# 0   10000 2018-04-27
# 1   10001 2018-04-28
# 2   10002 2018-04-29
# 3   10003 2018-04-30
# 4   10004 2018-05-01
# 5   10005 2018-05-02
# 6   10006 2018-05-03
# 7   10007 2018-05-04
# 8   10008 2018-05-05
# 9   10009 2018-05-06
# 10  10010 2018-05-07
# 11  10011 2018-05-08
# 12  10012 2018-05-09
# 13  10013 2018-05-10
# 14  10014 2018-05-11
# 15  10015 2018-05-12
# 16  10016 2018-05-13
# 17  10017 2018-05-14

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      18 non-null     int64
#  1   date    18 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 420.0 bytes

# %%
df_date = pd.read_excel( 'datefor19.xlsx', parse_dates=['date'] ).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      18 non-null     int64
#  1   date    18 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 420.0 bytes

# %%
df_date.astype( {'date':'datetime64[ns]'} ).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      18 non-null     int64
#  1   date    18 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 420.0 bytes

# %%
pd.to_datetime('2017-02-19')
# Out:
# Timestamp('2017-02-19 00:00:00')

# %%
pd.to_datetime(df_date['date'])
# Out:
# 0    2018-04-27
# 1    2018-04-28
# 2    2018-04-29
# 3    2018-04-30
# 4    2018-05-01
# 5    2018-05-02
# 6    2018-05-03
# 7    2018-05-04
# 8    2018-05-05
# 9    2018-05-06
# 10   2018-05-07
# 11   2018-05-08
# 12   2018-05-09
# 13   2018-05-10
# 14   2018-05-11
# 15   2018-05-12
# 16   2018-05-13
# 17   2018-05-14
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# ![image.png](attachment:b0c92cc0-0dfd-47db-963b-3ca760634414.png)

# %%
df_date['date'] = pd.to_datetime( df_date['date'], format='%Y-%m-%d' )

df_date
# Out:
#        id       date
# 0   10000 2018-04-27
# 1   10001 2018-04-28
# 2   10002 2018-04-29
# 3   10003 2018-04-30
# 4   10004 2018-05-01
# 5   10005 2018-05-02
# 6   10006 2018-05-03
# 7   10007 2018-05-04
# 8   10008 2018-05-05
# 9   10009 2018-05-06
# 10  10010 2018-05-07
# 11  10011 2018-05-08
# 12  10012 2018-05-09
# 13  10013 2018-05-10
# 14  10014 2018-05-11
# 15  10015 2018-05-12
# 16  10016 2018-05-13
# 17  10017 2018-05-14

# %%
df_date.dtypes
# Out:
# id               int64
# date    datetime64[ns]
# dtype: object

# %%
df_date['day_name'] = df_date['date'].dt.day_name()
df_date['day'] = df_date['date'].dt.day
df_date['month'] = df_date['date'].dt.month
df_date['weekday'] = df_date['date'].dt.weekday

df_date
# Out:
#        id       date   day_name  month  weekday  day
# 0   10000 2018-04-27     Friday      4        4   27
# 1   10001 2018-04-28   Saturday      4        5   28
# 2   10002 2018-04-29     Sunday      4        6   29
# 3   10003 2018-04-30     Monday      4        0   30
# 4   10004 2018-05-01    Tuesday      5        1    1
# 5   10005 2018-05-02  Wednesday      5        2    2
# 6   10006 2018-05-03   Thursday      5        3    3
# 7   10007 2018-05-04     Friday      5        4    4
# 8   10008 2018-05-05   Saturday      5        5    5
# 9   10009 2018-05-06     Sunday      5        6    6
# 10  10010 2018-05-07     Monday      5        0    7
# 11  10011 2018-05-08    Tuesday      5        1    8
# 12  10012 2018-05-09  Wednesday      5        2    9
# 13  10013 2018-05-10   Thursday      5        3   10
# 14  10014 2018-05-11     Friday      5        4   11
# 15  10015 2018-05-12   Saturday      5        5   12
# 16  10016 2018-05-13     Sunday      5        6   13
# ...

# %% [markdown]
# ## Диапазон дат

# %%
pd.date_range('2023-03-10', periods=10)
# Out:
# DatetimeIndex(['2023-03-10', '2023-03-11', '2023-03-12', '2023-03-13',
#                '2023-03-14', '2023-03-15', '2023-03-16', '2023-03-17',
#                '2023-03-18', '2023-03-19'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2023-03-10', periods=10, freq= 'ME') #MS, W, Y
# Out:
# DatetimeIndex(['2023-03-31', '2023-04-30', '2023-05-31', '2023-06-30',
#                '2023-07-31', '2023-08-31', '2023-09-30', '2023-10-31',
#                '2023-11-30', '2023-12-31'],
#               dtype='datetime64[ns]', freq='ME')

# %%
pd.date_range('2023-03-10', '2023-05-01', freq= 'ME')
# Out:
# DatetimeIndex(['2023-03-31', '2023-04-30'], dtype='datetime64[ns]', freq='ME')

# %%
pd.date_range('2023-03-10', '2023-05-01', periods=10)
# Out:
# DatetimeIndex(['2023-03-10 00:00:00', '2023-03-15 18:40:00',
#                '2023-03-21 13:20:00', '2023-03-27 08:00:00',
#                '2023-04-02 02:40:00', '2023-04-07 21:20:00',
#                '2023-04-13 16:00:00', '2023-04-19 10:40:00',
#                '2023-04-25 05:20:00', '2023-05-01 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
df_date.loc[df_date['date'] == '2018-05-04']
# Out:
#       id       date day_name  month  weekday  day
# 7  10007 2018-05-04   Friday      5        4    4
