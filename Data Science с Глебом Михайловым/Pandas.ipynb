# %% [markdown]
# # Загрузка данных через API kaggle

# %%
import kaggle

# %%
kaggle.api.dataset_download_files(dataset = "arashnic/hr-analytics-job-change-of-data-scientists", 
                                  path='data/', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/arashnic/hr-analytics-job-change-of-data-scientists

# %% [markdown]
# # Чтение данных

# %%
import pandas as pd

# %%
df = pd.read_csv('data/aug_train.csv', encoding='ISO-8859-1') # ISO-8859-1 - для западноевропейских языков, cp1251 - для кириллицы
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# # Основные операции с датафреймом

# %%
df[['city', 'city_development_index']] # обращение к столбцам
# Out:
#            city  city_development_index
# 0      city_103                   0.920
# 1       city_40                   0.776
# 2       city_21                   0.624
# 3      city_115                   0.789
# 4      city_162                   0.767
# ...         ...                     ...
# 19153  city_173                   0.878
# 19154  city_103                   0.920
# 19155  city_103                   0.920
# 19156   city_65                   0.802
# 19157   city_67                   0.855
#
# [19158 rows x 2 columns]

# %%
len(df) # строк в датафрейме
# Out:
# 19158

# %% [markdown]
# ## Удаление строк и столбцов

# %%
df.drop(['city'], axis = 1, inplace=True) # axis = 0 for rows, axis = 1 for columns
df.head()
# Out:
#    enrollee_id  city_development_index gender      relevent_experience  \
# 0         8949                   0.920   Male  Has relevent experience
# 1        29725                   0.776   Male   No relevent experience
# 2        11561                   0.624    NaN   No relevent experience
# 3        33241                   0.789    NaN   No relevent experience
# 4          666                   0.767   Male  Has relevent experience
#
#   enrolled_university education_level major_discipline experience  \
# 0       no_enrollment        Graduate             STEM        >20
# 1       no_enrollment        Graduate             STEM         15
# 2    Full time course        Graduate             STEM          5
# 3                 NaN        Graduate  Business Degree         <1
# 4       no_enrollment         Masters             STEM        >20
#
#   company_size    company_type last_new_job  training_hours  target
# 0          NaN             NaN            1              36     1.0
# ...

# %%
df = pd.read_csv('data/aug_train.csv', encoding='ISO-8859-1') # ISO-8859-1 - для западноевропейских языков, cp1251 - для кириллицы
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
df = df.drop(['city'], axis = 1) #перезапись, тк df.drop возвращает df без указанных столбцов
df.head()
# Out:
#    enrollee_id  city_development_index gender      relevent_experience  \
# 0         8949                   0.920   Male  Has relevent experience
# 1        29725                   0.776   Male   No relevent experience
# 2        11561                   0.624    NaN   No relevent experience
# 3        33241                   0.789    NaN   No relevent experience
# 4          666                   0.767   Male  Has relevent experience
#
#   enrolled_university education_level major_discipline experience  \
# 0       no_enrollment        Graduate             STEM        >20
# 1       no_enrollment        Graduate             STEM         15
# 2    Full time course        Graduate             STEM          5
# 3                 NaN        Graduate  Business Degree         <1
# 4       no_enrollment         Masters             STEM        >20
#
#   company_size    company_type last_new_job  training_hours  target
# 0          NaN             NaN            1              36     1.0
# ...

# %%
df = pd.read_csv('data/aug_train.csv', encoding='ISO-8859-1')

# %%
df.columns
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'last_new_job', 'training_hours', 'target'],
#       dtype='object')

# %%
df[['enrollee_id', 'city', 'city_development_index', 'gender',
       'relevent_experience', 'enrolled_university', 'education_level',
       'major_discipline', 'experience', 'company_size', 'company_type',
       'last_new_job', 'training_hours', 'target']].head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# ## Добавление столбцов

# %%
df['new_coll'] = 1 # создание нового столбца
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
df['new_coll_2'] = df['city_development_index'] / 3 # создание нового столбца на основе существующего столбца
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
df.assign(new_col_3 = 99) # добавляет столбец, но не сохраняет его в df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # Фильтрация и ворнинги

# %%
df[df['city'] == 'city_40'].head() # фильтр по логическому условию
# Out:
#      enrollee_id     city  city_development_index gender  \
# 1          29725  city_40                   0.776   Male
# 23          7041  city_40                   0.776   Male
# 363        28229  city_40                   0.776   Male
# 461        18620  city_40                   0.776   Male
# 827         1783  city_40                   0.776   Male
#
#          relevent_experience enrolled_university education_level  \
# 1     No relevent experience       no_enrollment        Graduate
# 23   Has relevent experience       no_enrollment        Graduate
# 363  Has relevent experience    Part time course        Graduate
# 461  Has relevent experience    Full time course        Graduate
# 827  Has relevent experience       no_enrollment         Masters
#
#     major_discipline experience company_size    company_type last_new_job  \
# 1               STEM         15        50-99         Pvt Ltd           >4
# 23        Humanities         <1    1000-4999         Pvt Ltd            1
# ...

# %%
df[(df['city'] == 'city_40') & (df['gender'] == 'Male')].head()
# Out:
#      enrollee_id     city  city_development_index gender  \
# 1          29725  city_40                   0.776   Male
# 23          7041  city_40                   0.776   Male
# 363        28229  city_40                   0.776   Male
# 461        18620  city_40                   0.776   Male
# 827         1783  city_40                   0.776   Male
#
#          relevent_experience enrolled_university education_level  \
# 1     No relevent experience       no_enrollment        Graduate
# 23   Has relevent experience       no_enrollment        Graduate
# 363  Has relevent experience    Part time course        Graduate
# 461  Has relevent experience    Full time course        Graduate
# 827  Has relevent experience       no_enrollment         Masters
#
#     major_discipline experience company_size    company_type last_new_job  \
# 1               STEM         15        50-99         Pvt Ltd           >4
# 23        Humanities         <1    1000-4999         Pvt Ltd            1
# ...

# %% [markdown]
# ## Метод query

# %%
df.query('city == "city_40" and gender == "Male"').head()
# Out:
#      enrollee_id     city  city_development_index gender  \
# 1          29725  city_40                   0.776   Male
# 23          7041  city_40                   0.776   Male
# 363        28229  city_40                   0.776   Male
# 461        18620  city_40                   0.776   Male
# 827         1783  city_40                   0.776   Male
#
#          relevent_experience enrolled_university education_level  \
# 1     No relevent experience       no_enrollment        Graduate
# 23   Has relevent experience       no_enrollment        Graduate
# 363  Has relevent experience    Part time course        Graduate
# 461  Has relevent experience    Full time course        Graduate
# 827  Has relevent experience       no_enrollment         Masters
#
#     major_discipline experience company_size    company_type last_new_job  \
# 1               STEM         15        50-99         Pvt Ltd           >4
# 23        Humanities         <1    1000-4999         Pvt Ltd            1
# ...

# %%
city_40_female = df[(df['city'] == 'city_40') & (df['gender'] == 'Female')].copy() # всегда делаем копию, чтобы не получить ворнинг
city_40_female['new_col_3'] = 1

# %%
city_40_female
# Out:
#        enrollee_id     city  city_development_index  gender  \
# 5625         18467  city_40                   0.776  Female
# 6385         11547  city_40                   0.776  Female
# 8032         24409  city_40                   0.776  Female
# 8046         27349  city_40                   0.776  Female
# 9923          6702  city_40                   0.776  Female
# 13871        17684  city_40                   0.776  Female
#
#            relevent_experience enrolled_university education_level  \
# 5625   Has relevent experience       no_enrollment         Masters
# 6385   Has relevent experience       no_enrollment        Graduate
# 8032    No relevent experience       no_enrollment         Masters
# 8046    No relevent experience       no_enrollment         Masters
# 9923    No relevent experience    Full time course        Graduate
# 13871  Has relevent experience       no_enrollment        Graduate
#
# ...

# %% [markdown]
# # Пропуски

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# company_type              0.320493
# company_size              0.309949
# gender                    0.235306
# major_discipline          0.146832
# education_level           0.024011
# last_new_job              0.022080
# enrolled_university       0.020148
# experience                0.003393
# enrollee_id               0.000000
# city                      0.000000
# city_development_index    0.000000
# relevent_experience       0.000000
# training_hours            0.000000
# target                    0.000000
# new_coll                  0.000000
# new_coll_2                0.000000
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# ...

# %%
df.dtypes
# Out:
# enrollee_id                 int64
# city                       object
# city_development_index    float64
# gender                     object
# relevent_experience        object
# enrolled_university        object
# education_level            object
# major_discipline           object
# experience                 object
# company_size               object
# company_type               object
# last_new_job               object
# training_hours              int64
# target                    float64
# new_coll                    int64
# new_coll_2                float64
# dtype: object

# %% [markdown]
# # Типы переменных

# %% [markdown]
# Непрерывная переменная - city_development_index
#
# Категориальная переменная (номинативная) - gender

# %%
df['city_development_index'].hist()
# Out:
# <Axes: >

# %%
df.describe() # сводка по числовым переменным
# Out:
#         enrollee_id  city_development_index  training_hours        target  \
# count  19158.000000            19158.000000    19158.000000  19158.000000
# mean   16875.358179                0.828848       65.366896      0.249348
# std     9616.292592                0.123362       60.058462      0.432647
# min        1.000000                0.448000        1.000000      0.000000
# 25%     8554.250000                0.740000       23.000000      0.000000
# 50%    16982.500000                0.903000       47.000000      0.000000
# 75%    25169.750000                0.920000       88.000000      0.000000
# max    33380.000000                0.949000      336.000000      1.000000
#
#        new_coll    new_coll_2
# count   19158.0  19158.000000
# mean        1.0      0.276283
# std         0.0      0.041121
# min         1.0      0.149333
# 25%         1.0      0.246667
# 50%         1.0      0.301000
# 75%         1.0      0.306667
# max         1.0      0.316333

# %% [markdown]
# ## value_counts

# %%
df['gender'].value_counts(dropna = False) # для номинативной переменной
# Out:
# gender
# Male      13221
# NaN        4508
# Female     1238
# Other       191
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# # Сортировка по столбцу

# %%
df.sort_values(by = ['city_development_index'], ascending=False).head()
# Out:
#        enrollee_id     city  city_development_index gender  \
# 8230         10878  city_98                   0.949   Male
# 8810         29934  city_98                   0.949   Male
# 3770         18838  city_98                   0.949   Male
# 10497         6754  city_98                   0.949   Male
# 18273         5742  city_98                   0.949   Male
#
#            relevent_experience enrolled_university education_level  \
# 8230   Has relevent experience       no_enrollment     High School
# 8810    No relevent experience       no_enrollment        Graduate
# 3770   Has relevent experience       no_enrollment         Masters
# 10497   No relevent experience       no_enrollment             Phd
# 18273  Has relevent experience       no_enrollment         Masters
#
#       major_discipline experience company_size   company_type last_new_job  \
# 8230               NaN          2          NaN            NaN            1
# ...

# %% [markdown]
# # Фильтрация по квантилям

# %%
q = df['city_development_index'].quantile(0.25)
q
# у 25% наблюдений значение city_development_index меньше 0.74
# Out:
# 0.74

# %%
df[df['city_development_index'] < q] # получили только типов с индексом меньше 0.74
# Out:
#        enrollee_id      city  city_development_index gender  \
# 2            11561   city_21                   0.624    NaN
# 10           29452   city_21                   0.624    NaN
# 13            5826   city_21                   0.624   Male
# 14            8722   city_21                   0.624    NaN
# 17            5764   city_21                   0.624    NaN
# ...            ...       ...                     ...    ...
# 19144        17191   city_21                   0.624    NaN
# 19145          155   city_44                   0.725    NaN
# 19147        21319   city_21                   0.624   Male
# 19148         9212   city_21                   0.624    NaN
# 19151        11385  city_149                   0.689   Male
#
#            relevent_experience enrolled_university education_level  \
# 2       No relevent experience    Full time course        Graduate
# 10      No relevent experience    Full time course     High School
# ...

# %%
(df['city_development_index'] < q).value_counts().iloc[1]
# Out:
# 4771

# %%
len(df[df['city_development_index'] < q]) / len(df)
# Out:
# 0.24903434596513205

# %%
q1 = df['city_development_index'].quantile(0.05)
q2 = df['city_development_index'].quantile(0.9)
print(f'q1 = {q1}, q2 = {q2}')
# Out:
# q1 = 0.624, q2 = 0.925

# %%
df['city_development_index'].hist()
# Out:
# <Axes: >

# %%
df[(df['city_development_index'] >= q1) & (df['city_development_index'] <= q2)]['city_development_index'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # Сводные таблицы

# %% [markdown]
# ## Категориальные переменные

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df['target'].mean()
# Out:
# 0.24934753105752167

# %%
df.groupby('gender')['target'].mean()
# Out:
# gender
# Female    0.263328
# Male      0.227819
# Other     0.261780
# Name: target, dtype: float64

# %%
t = df.groupby('gender')['target'].agg(['count', 'mean'])
t
# Out:
#         count      mean
# gender
# Female   1238  0.263328
# Male    13221  0.227819
# Other     191  0.261780

# %%
t['count'].sum()
# Out:
# 14650

# %%
len(df)
# Out:
# 19158

# %%
t['count'].sum() == len(df)
# Out:
# False

# %%
t = df.groupby('gender', dropna = False)['target'].agg(['count', 'mean'])
t
# Out:
#         count      mean
# gender
# Female   1238  0.263328
# Male    13221  0.227819
# Other     191  0.261780
# NaN      4508  0.308119

# %%
t['count'].sum()
# Out:
# 19158

# %%
t['count'].sum() == len(df)
# Out:
# True

# %%
ed = df.groupby('education_level', dropna = False)['target'].agg(['count', 'mean'])
ed.sort_values(by='mean', ascending = False)
# Out:
#                  count      mean
# education_level
# Graduate         11598  0.279790
# NaN                460  0.226087
# Masters           4361  0.214400
# High School       2017  0.195340
# Phd                414  0.140097
# Primary School     308  0.133117

# %%
df.groupby('education_level', dropna = False)['target'].mean().plot(kind = 'bar')
# Out:
# <Axes: xlabel='education_level'>

# %% [markdown]
# ## Непрерывные переменные

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df.groupby('city_development_index', dropna = False)['target'].agg(['count', 'mean'])
# Out:
#                         count      mean
# city_development_index
# 0.448                      17  0.647059
# 0.479                      28  0.535714
# 0.487                       5  0.800000
# 0.493                      13  0.538462
# 0.512                       5  0.600000
# ...                       ...       ...
# 0.924                     301  0.093023
# 0.925                     171  0.140351
# 0.926                    1336  0.099551
# 0.939                     497  0.092555
# 0.949                      79  0.101266
#
# [93 rows x 2 columns]

# %%
df['city_development_index_group'] = pd.cut(df['city_development_index'], 5)
# создает 5 равных интервалов и определяет каждое наблюдение в соответствующий интервал

# %%
df.groupby('city_development_index_group', dropna = False)['target'].agg(['count', 'mean'])
# Out:
# C:\Users\ryagu\AppData\Local\Temp\ipykernel_19596\3014875797.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('city_development_index_group', dropna = False)['target'].agg(['count', 'mean'])
#                               count      mean
# city_development_index_group
# (0.447, 0.548]                  178  0.578652
# (0.548, 0.648]                 3297  0.582651
# (0.648, 0.749]                 1529  0.273381
# (0.749, 0.849]                 1949  0.194459
# (0.849, 0.949]                12205  0.160262

# %%
df['city_development_index'].hist()
# Out:
# <Axes: >

# %%
df['city_development_index_group_q'] = pd.qcut(df['city_development_index'], 5, duplicates = 'drop')

# %%
t = df.groupby('city_development_index_group_q', dropna = False)['target'].agg(['count', 'mean'])
t
# Out:
# C:\Users\ryagu\AppData\Local\Temp\ipykernel_19596\3396288298.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   t = df.groupby('city_development_index_group_q', dropna = False)['target'].agg(['count', 'mean'])
#                                 count      mean
# city_development_index_group_q
# (0.447, 0.691]                   3869  0.550530
# (0.691, 0.878]                   3827  0.206428
# (0.878, 0.92]                    8925  0.178375
# (0.92, 0.949]                    2537  0.104454

# %%
t['count'].sum()
# Out:
# 19158

# %%
t['mean'].plot()
# Out:
# <Axes: xlabel='city_development_index_group_q'>

# %%
df['city_development_index_group_custom'] = pd.cut(df['city_development_index'], 
                                                   [-float('inf'), 0.3, 0.65, 0.85, 1])

# %%
df.groupby('city_development_index_group_custom', dropna = False)['target'].agg(['count', 'mean'])
# Out:
# C:\Users\ryagu\AppData\Local\Temp\ipykernel_19596\1697434433.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('city_development_index_group_custom', dropna = False)['target'].agg(['count', 'mean'])
#                                      count      mean
# city_development_index_group_custom
# (-inf, 0.3]                              0       NaN
# (0.3, 0.65]                           3479  0.582064
# (0.65, 0.85]                          3474  0.229131
# (0.85, 1.0]                          12205  0.160262

# %% [markdown]
# # Перегруппировка категориальных переменных

# %%
df.groupby('education_level', dropna = False)['target'].agg(['count', 'mean'])
# Out:
#                  count      mean
# education_level
# Graduate         11598  0.279790
# High School       2017  0.195340
# Masters           4361  0.214400
# Phd                414  0.140097
# Primary School     308  0.133117
# NaN                460  0.226087

# %%
def education_group(x):
    if x in ['High School', 'Primary School']:
        return 'School'
    elif x in ['Masters', 'Phd']:
        return 'Masters_and_phd'
    else:
        return x

# %%
df['new_education_level']= df['education_level'].apply(education_group)

# %%
df.groupby('new_education_level', dropna=False)['target'].agg(['count', 'mean'])
# Out:
#                      count      mean
# new_education_level
# Graduate             11598  0.279790
# Masters_and_phd       4775  0.207958
# School                2325  0.187097
# NaN                    460  0.226087

# %%
d = {'Primary School':'School', 'High School': 'School'}

# %%
df['education_level'].map(d)
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#           ...
# 19153       NaN
# 19154       NaN
# 19155       NaN
# 19156    School
# 19157    School
# Name: education_level, Length: 19158, dtype: object

# %% [markdown]
# # Функции с несколькими столбцами

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
def new_training_hours(row):
    if row['education_level'] == 'Phd':
        return row['training_hours'] + 1000
    else:
        return row['training_hours']

# %%
df['new_training_hours'] = df.apply(new_training_hours, axis = 1)

# %%
df[df['education_level'] == 'Phd']
# Out:
#        enrollee_id      city  city_development_index gender  \
# 37           10164  city_114                   0.926   Male
# 121          13915   city_16                   0.910   Male
# 130           3921   city_36                   0.893    NaN
# 135          23947  city_103                   0.920    NaN
# 152          31786  city_103                   0.920   Male
# ...            ...       ...                     ...    ...
# 18738         1477  city_162                   0.767   Male
# 18800        18365  city_103                   0.920   Male
# 18807          229  city_114                   0.926   Male
# 18944         2678  city_104                   0.924    NaN
# 19044        14441   city_89                   0.925   Male
#
#            relevent_experience enrolled_university education_level  \
# 37     Has relevent experience       no_enrollment             Phd
# 121    Has relevent experience       no_enrollment             Phd
# ...

# %% [markdown]
# # Pivot table (отличия от groupby)

# %%
df.groupby('new_education_level', dropna=False)['target'].agg(['count', 'mean'])
# Out:
#                      count      mean
# new_education_level
# Graduate             11598  0.279790
# Masters_and_phd       4775  0.207958
# School                2325  0.187097
# NaN                    460  0.226087

# %%
df['new_education_level'] = df['new_education_level'].fillna('no_info') # заполнил пропуски

# %%
t = df.pivot_table(index = 'new_education_level', values = 'target', aggfunc = ['count', 'mean'])
t
# теперь пропуски показываются в таблице
# Out:
#                      count      mean
#                     target    target
# new_education_level
# Graduate             11598  0.279790
# Masters_and_phd       4775  0.207958
# School                2325  0.187097
# no_info                460  0.226087

# %%
t.reset_index(['new_education_level']) # можно как бы убрать индексы строки в значения столбца
# Out:
#   new_education_level  count      mean
#                       target    target
# 0            Graduate  11598  0.279790
# 1     Masters_and_phd   4775  0.207958
# 2              School   2325  0.187097
# 3             no_info    460  0.226087

# %% [markdown]
# ## Избавляемся от мультииндекса

# %%
t.columns = ['_'.join(col).strip() for col in t.columns.values] # строчка для того, чтобы убрать мультииндекс

# %%
t.columns
# Out:
# Index(['count_target', 'mean_target'], dtype='object')

# %%
for col in t.columns.values:
    print(col)
# Out:
# count_target
# mean_target

# %%
t = t.reset_index('new_education_level') # готовая таблица 
t
# Out:
#   new_education_level  count_target  mean_target
# 0            Graduate         11598     0.279790
# 1     Masters_and_phd          4775     0.207958
# 2              School          2325     0.187097
# 3             no_info           460     0.226087

# %% [markdown]
# ## Фича Pivot table (новые перем)

# %%
df.pivot_table(index = 'new_education_level', values = 'target', aggfunc = ['count', 'mean'])
# Out:
#                      count      mean
#                     target    target
# new_education_level
# Graduate             11598  0.279790
# Masters_and_phd       4775  0.207958
# School                2325  0.187097
# no_info                460  0.226087

# %%
df.pivot_table(index = 'new_education_level', columns='gender', values = 'target', aggfunc = ['count', 'mean'])
# Out:
#                      count                  mean
# gender              Female  Male Other    Female      Male     Other
# new_education_level
# Graduate               773  8144   112  0.279431  0.257122  0.330357
# Masters_and_phd        386  3237    31  0.233161  0.186284  0.096774
# School                  71  1598    39  0.267606  0.171464  0.205128
# no_info                  8   242     9  0.125000  0.169421  0.222222

# %%
df.groupby(['new_education_level','gender'], dropna=False)['target'].agg(['count', 'mean'])
# Out:
#                             count      mean
# new_education_level gender
# Graduate            Female    773  0.279431
#                     Male     8144  0.257122
#                     Other     112  0.330357
#                     NaN      2569  0.349552
# Masters_and_phd     Female    386  0.233161
#                     Male     3237  0.186284
#                     Other      31  0.096774
#                     NaN      1121  0.264942
# School              Female     71  0.267606
#                     Male     1598  0.171464
#                     Other      39  0.205128
#                     NaN       617  0.217180
# no_info             Female      8  0.125000
#                     Male      242  0.169421
#                     Other       9  0.222222
#                     NaN       201  0.298507

# %% [markdown]
# # Heatmap (визуал)

# %%
df['gender'] = df['gender'].fillna('no_info')

# %%
t = df.pivot_table(index = 'new_education_level', columns='gender', values = 'target', aggfunc = ['mean'])
t
# Out:
#                          mean
# gender                 Female      Male     Other   no_info
# new_education_level
# Graduate             0.279431  0.257122  0.330357  0.349552
# Masters_and_phd      0.233161  0.186284  0.096774  0.264942
# School               0.267606  0.171464  0.205128  0.217180
# no_info              0.125000  0.169421  0.222222  0.298507

# %%
import seaborn as sns

# %%
sns.heatmap(t)
# Out:
# <Axes: xlabel='None-gender', ylabel='new_education_level'>

# %%
df.pivot_table(index = 'new_education_level', columns='gender', values = 'target', aggfunc = ['count'])
# Out:
#                      count
# gender              Female  Male Other no_info
# new_education_level
# Graduate               773  8144   112    2569
# Masters_and_phd        386  3237    31    1121
# School                  71  1598    39     617
# no_info                  8   242     9     201

# %% [markdown]
# # Корреляция и phik

# %%
df[['city_development_index', 'training_hours', 'target']].corr(numeric_only=True, method = 'pearson')
# Out:
#                         city_development_index  training_hours    target
# city_development_index                1.000000        0.001920 -0.341665
# training_hours                        0.001920        1.000000 -0.021577
# target                               -0.341665       -0.021577  1.000000

# %%
sns.heatmap(df[['city_development_index', 'training_hours', 'target']].corr(numeric_only=True))
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
df.plot(kind = 'scatter', x = 'city_development_index', y = 'training_hours')
# Out:
# <Axes: xlabel='city_development_index', ylabel='training_hours'>

# %%
! pip install phik
# Out:
# ...
#    ---------------------------------------- 0.0/676.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/676.2 kB ? eta -:--:--
#    ---------------------------------------- 676.2/676.2 kB 2.7 MB/s eta 0:00:00
# ...
# WARNING: Ignoring invalid distribution ~upyterlab (D:\Anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (D:\Anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (D:\Anaconda\Lib\site-packages)

# %%
import phik
from phik.report import plot_correlation_matrix
from phik import report

# %%
phik_overview = df.phik_matrix()
phik_overview
# Out:
# interval columns not set, guessing: ['enrollee_id', 'city_development_index', 'training_hours', 'target', 'new_coll', 'new_coll_2', 'new_training_hours']
# D:\Anaconda\Lib\site-packages\phik\data_quality.py:72: UserWarning: Not enough unique value for variable new_coll for analysis 1. Dropping this column
#   warnings.warn(
#                                      enrollee_id      city  \
# enrollee_id                             1.000000  0.214019
# city                                    0.214019  1.000000
# city_development_index                  0.125181  1.000000
# gender                                  0.125045  0.235773
# relevent_experience                     0.073145  0.152621
# enrolled_university                     0.051188  0.376293
# education_level                         0.076123  0.363706
# major_discipline                        0.030968  0.178508
# experience                              0.086949  0.346552
# ...

# %%
sns.heatmap(phik_overview)
# Out:
# <Axes: >

# %%
phik_overview['target'].sort_values(ascending=False)
# Out:
# target                                 1.000000
# city_development_index_group_custom    0.538014
# city_development_index_group_q         0.523691
# city_development_index                 0.482287
# new_coll_2                             0.482287
# city                                   0.477283
# city_development_index_group           0.302403
# experience                             0.238725
# relevent_experience                    0.199859
# new_education_level                    0.132478
# gender                                 0.116653
# last_new_job                           0.114708
# enrolled_university                    0.093803
# education_level                        0.075999
# company_size                           0.071953
# enrollee_id                            0.067472
# company_type                           0.066792
# new_training_hours                     0.054314
# major_discipline                       0.029200
# training_hours                         0.026849
# ...

# %% [markdown]
# # Проверка связей

# %%
df['city_development_index_group_q']
# Out:
# 0         (0.878, 0.92]
# 1        (0.691, 0.878]
# 2        (0.447, 0.691]
# 3        (0.691, 0.878]
# 4        (0.691, 0.878]
#               ...
# 19153    (0.691, 0.878]
# 19154     (0.878, 0.92]
# 19155     (0.878, 0.92]
# 19156    (0.691, 0.878]
# 19157    (0.691, 0.878]
# Name: city_development_index_group_q, Length: 19158, dtype: category
# Categories (4, interval[float64, right]): [(0.447, 0.691] < (0.691, 0.878] < (0.878, 0.92] < (0.92, 0.949]]

# %%
df.groupby('city_development_index_group_q')['target'].agg(['count', 'mean'])
# Out:
# C:\Users\ryagu\AppData\Local\Temp\ipykernel_19596\2482842003.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('city_development_index_group_q')['target'].agg(['count', 'mean'])
#                                 count      mean
# city_development_index_group_q
# (0.447, 0.691]                   3869  0.550530
# (0.691, 0.878]                   3827  0.206428
# (0.878, 0.92]                    8925  0.178375
# (0.92, 0.949]                    2537  0.104454

# %%
t = df.groupby('city')['target'].agg(['count', 'mean'])
t
# Out:
#           count      mean
# city
# city_1       26  0.115385
# city_10      86  0.104651
# city_100    275  0.236364
# city_101     75  0.573333
# city_102    304  0.171053
# ...         ...       ...
# city_93      26  0.192308
# city_94      26  0.384615
# city_97     104  0.076923
# city_98      79  0.101266
# city_99      94  0.159574
#
# [123 rows x 2 columns]

# %%
t.sort_values('count', ascending=False).head(10)
# Out:
#           count      mean
# city
# city_103   4355  0.213088
# city_21    2702  0.591044
# city_16    1533  0.116765
# city_114   1336  0.099551
# city_160    845  0.235503
# city_136    586  0.104096
# city_67     431  0.132251
# city_75     305  0.101639
# city_102    304  0.171053
# city_104    301  0.093023

# %%
t.sort_values('count', ascending=False).head(10)['mean'].plot(kind = 'bar')
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# `Скорее всего в городе city_21 низкий city_development_index. Проверим это`

# %%
t = df.groupby('city')[['target', 'city_development_index']].agg(['count', 'mean'])
t
# Out:
#          target           city_development_index
#           count      mean                  count   mean
# city
# city_1       26  0.115385                     26  0.847
# city_10      86  0.104651                     86  0.895
# city_100    275  0.236364                    275  0.887
# city_101     75  0.573333                     75  0.558
# city_102    304  0.171053                    304  0.804
# ...         ...       ...                    ...    ...
# city_93      26  0.192308                     26  0.865
# city_94      26  0.384615                     26  0.698
# city_97     104  0.076923                    104  0.925
# city_98      79  0.101266                     79  0.949
# city_99      94  0.159574                     94  0.915
#
# [123 rows x 4 columns]

# %%
t.columns = ['_'.join(col).strip() for col in t.columns.values]

# %%
t.sort_values('target_count', ascending=False).head(10)
# гипотеза подтвердилась
# Out:
#           target_count  target_mean  city_development_index_count  \
# city
# city_103          4355     0.213088                          4355
# city_21           2702     0.591044                          2702
# city_16           1533     0.116765                          1533
# city_114          1336     0.099551                          1336
# city_160           845     0.235503                           845
# city_136           586     0.104096                           586
# city_67            431     0.132251                           431
# city_75            305     0.101639                           305
# city_102           304     0.171053                           304
# city_104           301     0.093023                           301
#
#           city_development_index_mean
# city
# city_103                        0.920
# city_21                         0.624
# city_16                         0.910
# city_114                        0.926
# ...

# %%
# смотрим на опыт, делаем замену, заполняем наны и преобразовываем в int
df['experience_int'] = df['experience'].replace('<1', '0').replace('>20', '999').fillna(-1).astype(int)

# %%
# делим на 5 интервалов
df['experience_group'] = pd.qcut(df['experience_int'], 5)

# %%
# группируем по experience_group
df.groupby('experience_group')['target'].agg(['count', 'mean'])
# видим линейную зависимость между experience_group и target(желанием сменить работу), что показывал phik.
# Out:
# C:\Users\ryagu\AppData\Local\Temp\ipykernel_19596\1337073001.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('experience_group')['target'].agg(['count', 'mean'])
#                   count      mean
# experience_group
# (-1.001, 4.0]      5020  0.358964
# (4.0, 6.0]         2646  0.285336
# (6.0, 11.0]        4459  0.239740
# (11.0, 18.0]       3295  0.170561
# (18.0, 999.0]      3738  0.157571

# %%
df.groupby('experience_group')['target'].agg(['mean']).plot(kind = 'bar')
# Out:
# C:\Users\ryagu\AppData\Local\Temp\ipykernel_19596\396857234.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('experience_group')['target'].agg(['mean']).plot(kind = 'bar')
# <Axes: xlabel='experience_group'>

# %% [markdown]
# # Игрушечные данные

# %%
t = pd.DataFrame({'col1': [1, 2, 3, float('nan')],
                  'col2': ['a', 'b', 'c', 'd'],
                  'col3': [0]*3 + [1]*1}
                )
t
# Out:
#    col1 col2  col3
# 0   1.0    a     0
# 1   2.0    b     0
# 2   3.0    c     0
# 3   NaN    d     1

# %% [markdown]
# # Функции агрегации с пропусками

# %%
t = pd.DataFrame({'col1': [1, 2, 3, float('nan')]})
t
# Out:
#    col1
# 0   1.0
# 1   2.0
# 2   3.0
# 3   NaN

# %%
t['col1'].sum()
# Out:
# 6.0

# %%
t['col1'].mean()
# Out:
# 2.0

# %%
t['col1'].count()
# Out:
# 3

# %%
len(t)
# Out:
# 4

# %% [markdown]
# # Визуализация данных

# %%
df['city_development_index'].hist()
# Out:
# <Axes: >

# %%
df['gender'].value_counts()
# Out:
# gender
# Male       13221
# no_info     4508
# Female      1238
# Other        191
# Name: count, dtype: int64

# %%
df['gender'].hist()
# Out:
# <Axes: >

# %%
df['gender'] = df['gender'].replace('no_info', float('nan'))

# %%
df['gender'].hist() # не увидит пропуски
# Out:
# <Axes: >

# %%
df['gender'].value_counts(dropna=False).plot(kind = 'bar')
# Out:
# <Axes: xlabel='gender'>

# %% [markdown]
# # Scatter plot

# %%
t = pd.DataFrame({'x': [1, 2, 3],
                  'y': [1, 3, 2]})
t
# Out:
#    x  y
# 0  1  1
# 1  2  3
# 2  3  2

# %%
t.plot(x = 'x', y = 'y', kind = 'scatter')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df[df['experience_int'] < 999].plot(x = 'city_development_index', y = 'experience_int', kind = 'scatter', alpha = 0.01)
# Out:
# <Axes: xlabel='city_development_index', ylabel='experience_int'>

# %%
(df[df['experience_int'] < 999].groupby('city_development_index_group_q')
['experience_int'].agg(['count', 'mean', 'median']))
# Out:
# C:\Users\ryagu\AppData\Local\Temp\ipykernel_19596\1694691463.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df[df['experience_int'] < 999].groupby('city_development_index_group_q')
#                                 count      mean  median
# city_development_index_group_q
# (0.447, 0.691]                   3768  5.603238     5.0
# (0.691, 0.878]                   3408  7.936620     7.0
# (0.878, 0.92]                    6733  8.576860     8.0
# (0.92, 0.949]                    1963  9.099338     9.0

# %% [markdown]
# чем больше city_development_index тем больше среднее (mean) количество лет опыта

# %%
(df[df['experience_int'] < 999].groupby('city_development_index_group_q')
['experience_int'].mean()).plot()
# Out:
# C:\Users\ryagu\AppData\Local\Temp\ipykernel_19596\3792965894.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (df[df['experience_int'] < 999].groupby('city_development_index_group_q')
# <Axes: xlabel='city_development_index_group_q'>

# %% [markdown]
# # Джойны

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
age = df[['enrollee_id']].copy()

# %%
age['age'] = 30
age
# Out:
#        enrollee_id  age
# 0             8949   30
# 1            29725   30
# 2            11561   30
# 3            33241   30
# 4              666   30
# ...            ...  ...
# 19153         7386   30
# 19154        31398   30
# 19155        24576   30
# 19156         5756   30
# 19157        23834   30
#
# [19158 rows x 2 columns]

# %%
df = df.merge(age, how = 'left', on = 'enrollee_id')
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
len(df)
# Out:
# 19158

# %% [markdown]
# # Numpy

# %%
type(df['city_development_index'].values)
# Out:
# numpy.ndarray

# %%
import numpy as np

# %%
np.mean([1, 2, 3, 4, 5])
# Out:
# 3.0

# %%
np.random.normal()
# Out:
# 0.08606952747239592

# %%
list(range(-10, 10, 2))
# Out:
# [-10, -8, -6, -4, -2, 0, 2, 4, 6, 8]

# %%
np.arange(-10, 10, 0.5)
# Out:
# array([-10. ,  -9.5,  -9. ,  -8.5,  -8. ,  -7.5,  -7. ,  -6.5,  -6. ,
#         -5.5,  -5. ,  -4.5,  -4. ,  -3.5,  -3. ,  -2.5,  -2. ,  -1.5,
#         -1. ,  -0.5,   0. ,   0.5,   1. ,   1.5,   2. ,   2.5,   3. ,
#          3.5,   4. ,   4.5,   5. ,   5.5,   6. ,   6.5,   7. ,   7.5,
#          8. ,   8.5,   9. ,   9.5])

# %%
np.linspace(-10, 10, 30)
# Out:
# array([-10.        ,  -9.31034483,  -8.62068966,  -7.93103448,
#         -7.24137931,  -6.55172414,  -5.86206897,  -5.17241379,
#         -4.48275862,  -3.79310345,  -3.10344828,  -2.4137931 ,
#         -1.72413793,  -1.03448276,  -0.34482759,   0.34482759,
#          1.03448276,   1.72413793,   2.4137931 ,   3.10344828,
#          3.79310345,   4.48275862,   5.17241379,   5.86206897,
#          6.55172414,   7.24137931,   7.93103448,   8.62068966,
#          9.31034483,  10.        ])

# %%
np.random.uniform(size = 10) / 100 # генерится шум
# Out:
# array([0.00997251, 0.00096115, 0.00093833, 0.00905867, 0.00294926,
#        0.00189379, 0.00174749, 0.00632862, 0.00257245, 0.00337193])

# %%
a = [1, 2, 3]
b = [2, 2, 2]
a+b
# Out:
# [1, 2, 3, 2, 2, 2]

# %%
a = np.array([1, 2, 3])
b = np.array([2, 2, 2])
a + b
# Out:
# array([3, 4, 5])

# %%
a*b
# Out:
# array([2, 4, 6])

# %%
pd.DataFrame(a)
# Out:
#    0
# 0  1
# 1  2
# 2  3
