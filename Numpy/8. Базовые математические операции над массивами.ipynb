# %%
import numpy as np

# %% [markdown]
# ## Массивы и числа

# %%
a = np.array([1, 2, 3])
print(a)
# Out:
# [1 2 3]

# %%
print(-a)
# Out:
# [-1 -2 -3]

# %%
print(a - 3)
# Out:
# [-2 -1  0]

# %%
print(a + 2)
# Out:
# [3 4 5]

# %%
print(a * 5)
# Out:
# [ 5 10 15]

# %%
print(a / 2)
# Out:
# [0.5 1.  1.5]

# %%
print(a // 2)
# Out:
# [0 1 1]

# %%
print(a ** 3)
# Out:
# [ 1  8 27]

# %% [markdown]
# ## Массивы и массивы

# %%
b = np.array([3, 4, 5])
print(b)
# Out:
# [3 4 5]

# %%
print(a + b)
print(a * b)
print(a / b)
print(a // b)
print(a ** b)
# Out:
# [4 6 8]
# [ 3  8 15]
# [0.33333333 0.5        0.6       ]
# [0 0 0]
# [  1  16 243]

# %%
#транслирование массивов

# %%
b = np.arange(1, 7)
b.resize(2, 3)
print(a)
print(b)
print(a + b)
# Out:
# [1 2 3]
# [[1 2 3]
#  [4 5 6]]
# [[2 4 6]
#  [5 7 9]]

# %% [markdown]
# ## Расширенные аналоги

# %%
a = np.array([1, 2, 6, 8])
print(a)
# Out:
# [1 2 6 8]

# %%
a +=5
print(a)
# Out:
# [11 12 16 18]

# %%
a -= 5
print(a)
# Out:
# [ 6  7 11 13]

# %%
b = np.ones(4)
b *= a
print(b)
# Out:
# [ 6.  7. 11. 13.]

# %%
a +=b # несоответствие типов

# %%
print((a + b) * 5 -10)
# Out:
# [ 50.  60. 100. 120.]
