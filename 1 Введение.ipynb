# %% [markdown]
# # 1.2 Основные понятия

# %% [markdown]
# ## Проблема

# %% [markdown]
# Допустим, у нас есть игра.
#
# Пользователи скачивают её на мобильный телефон, создают эпического фентезийного персонажа, и отправляются в путешествие по интересному миру со всякими драконами, гоблинами и т.д.
#
# И вот одни пользователи, ну, вообще молодцы: скачивают приложение, каждый день в него играют, покупают всякие мечи за деньги дополнительные, retention у них высокий, arpu на юзера просто замечательный - всё круто.
#
# А другие пользователи скачали приложение, пару раз поиграли, удалили и больше никогда к нам не возвращались.
#
# Возникает вопрос: а можно ли с этим что-то сделать? `Можно ли как-то повлиять на то - останется ли пользователь в нашем приложении или удалит и больше никогда не вернётся?`
#
# И это первая очень понятная стадия любой задачи, в которой машинное обучение используется. Умение видеть проблему, которую нужно решить - ключевая компетенция любого data-scientist'а. Без этого никакое машинное обучение в принципе и не нужно.
#
# Далее, как только мы сформулировали некоторую проблему, которая сформулирована на языке продуктовой задачи - как избежать того, что пользователи перестают пользоваться приложением.
#
# Далее переводим её на язык машинного обучения - поняли, что это задача классификации или регрессии и для решения мы будем использовать логистическую регрессию.

# %% [markdown]
# ## Data engineering

# %% [markdown]
# Так вот в любом случае, чтобы использовать логистическую регрессию нам нужны данные. Без данных мы никакую регрессию не применим, и если мы говорим про наш пример, понятное дело нужно логировать события пользователей внутри игры и где-то их хранить. `Логирование` — это процесс записи и структурирования информации о работе системы в специальные файлы, называемые лог-файлами. Эти файлы содержат данные о событиях, ошибках, действиях пользователей и других аспектах работы системы.
#
# И это отдельная огромная область знаний, которая называется data engineering, отвечающая на вопросы:
#
# - как нам хранить данные?
# - где их хранить?
# - как обеспечить хранение миллиардов данных, которые могут происходить в нашем приложении
#
# И это тоже очень важная компетенция любого data-scientist.

# %% [markdown]
# ## Machine learning

# %% [markdown]
# Приблизительно после этого возникает время машинного обучения - когда мы сформулировали проблему, сохранили данные, теперь можно подумать о том, как нам обучить регрессию.
#
# После того как мы это сделали, нужно результат нашего машинного обучения как-то внедрить в продукт.

# %% [markdown]
# ## Programming

# %% [markdown]
# Пофантазируем - мы подумали, что тем пользователям, которым мы предсказали высокую вероятность ухода, мы покажем рекламную плашку "купи новый меч". Для этого нам нужно изменить исходный код игры, реализовать логику машинного обучения, внедрить её в наш продукт и как-то запрограммировать это всё.
#
# Всё вместе это по-прежнему не отвечает на наш вопрос. Допустим, мы это сделали и пользователи, которые видят эту плашку, покупают мечи бесплатно. Здесь интуитивно понятно, что надо проверить, а работает ли наше решение. Т.е. что происходит с теми игроками, которых появилась плашка и теми, у которых эта плашка не появилась. Перестают ли они уходить?

# %% [markdown]
# ## Analytics

# %% [markdown]
# Допустим, у нас есть 2 группы (экс и контрольная). Одним пользователям, которым мы предсказали высокую вероятность ухода, ничего не показывать. А другим показать плашку про бесплатный меч.
#
# А потом, например через недельку, посмотреть результат - а правда ли, что для тех пользователей, которым мы предсказывали уход из игры и которым мы показали плашку с рекламой, ситуация стала лучше.

# %% [markdown]
# ## Data Science

# %% [markdown]
# Все предыдущие пункты вместе называются data science. В идеальном мире, человек, занимающийся машинным обучением и data science, может сам взяться за все стадии этой задачи.
#
# На практике этим занимается команда людей с понятными пересекающимися ролями. Баланс сил относит человека к какой-то одной из соответствующих областей.

# %% [markdown]
# ## Этапы Machine learning

# %% [markdown]
# ### Формулирование проблемы на языке машинного обучения

# %% [markdown]
# Одна из самых творческих задач – это умение переформулировать задачу на язык машинного обучения. В примере, который рассматривали ранее, система сама подсказывала возможные методы решения.
#
# Как нам понять расстанется ли игрок с нами или продолжит пользоваться нашим приложением? Т.е. задача намекает на то, что возможно это задача классификации и возможно классом является тот факт, что человек играет или не играет. Это подсказывает нам как организовать подготовку данных, как разметить нашу выборку и какой метод машинного обучения использовать.
#
# Какие данные нужно собрать? Как их подготовить? Как переформулировать задачу на понятный для машинного обучения язык?
#
# И мы попробуем с этим поработать в рамках курса.

# %% [markdown]
# ### Data preparation

# %% [markdown]
# Следующая стадия в обучении любой модели – подготовка данных. Это огромная, очень важная тема, связанная с чисткой данных с feature engineering (извлечение из данных тех показателей, которые мы хотим использовать для обучения модели). Например, в случае линейной регрессии, скажем это извлечение из данных зависимых переменных, для того чтобы предсказать независимую. Это зачастую не так-то просто как кажется, и это очень важная часть машинного обучения, и об этом мы также поговорим.
#
# Рассмотрим пример: данные поведения игроков из воображаемой игры могли бы быть сохранены в таком виде:
# | user_id | user_name | event | platform | time |
# |------------|-------------|-------------|-------------|-------------|
# | 1 |	Boromir |	start_game	| android |	1550690622 |
# | 1 |	Boromir	| purchase_sword |	android |	1550690623 |
# | 1 |	Boromir	| kill_goblin |	android	| 1550690624 |
# | 1 |	Boromir	| kill_goblin |	android	| 1550690625 |
# | 1 |	Boromir	| kill_goblin |	android	| 1550690626 |
# | 1 |	Boromir	| kill_goblin |	android	| 1550690627 |
# | 1 |	Boromir	| killed_by_goblin |	android	| 1550690628 |
#
# Где мы для каждого игрока пишем время, событие и какой-то идентификатор, чтобы понять - события какого игрока мы наблюдаем.
#
# Понятное дело, что данные в таком виде хранятся, мы их так записываем, они так хранятся в csv-файле, который дал нам data-engineer и сказал: «Вот применяй модель машинного обучения». Однако, данные не позволяют нам ничего сделать.
#
# Нужно их переструктурировать, переформировать, извлечь из них нужные признаки, разметить нашу выборку и т.д. Зачастую это важный процесс, позволяющий нам понять, что пользователь ушёл или не ушёл, и как вообще это определить? Игрок не заходил месяц, или два? Мы подумаем какие feature можно придумать – сколько гоблинов убил пользователь или сколько игр сыграл, ни разу не проиграв.
#
# Всё это преобразует наш исходный dataframe в новый, где в качестве колонок будут признаки объекта, которые мы хотим использовать для обучения нашей модели, а в какой-то ещё колонке (часто её называют y) будет некоторый класс – например 1 или 0, в том смысле ушёл человек из игры или нет. Мы позже обсудим это подробнее.

# %% [markdown]
# ### Machine learning

# %% [markdown]
# После того, как мы взяли сырые данные и как-то их переформулировали, переструктурировали, агрегировали и подготовили их, чтобы можно было применить машинное обучение наступает этап применения машинного обучения.
#
# В большинстве случаев это код, написанный на python или другом языке программирования, который использует разные методы машинного обучения (например, регрессию, нейросеть, дерево решений) и обучает нашу модель. Мы ещё подробнее поговорим о том, что значит обучить модель.

# %% [markdown]
# ### Validation

# %% [markdown]
# После того, как мы применили модель машинного обучения – сажем, сформировали регрессию, подобрали коэффициенты и сможем теперь предсказывать наш класс – 0 или 1 происходит очень важный этап – валидация модели.
#
# Мы хотим убедиться, что наша модель может выше случайного предсказывать нашу исходную переменную. Она действительно работает и как в этом убедиться и какие могут быть проблемы с тем, когда это не так. И как вообще понять, что есть проблема.
#
# В курсе по статистики мы не занимались какой-либо валидацией. Мы реализовывали метод и выполняли его, никак не валидируя себя. А в методах машинного обучения это отдельная важная стадия как именно убедиться в том, что наша модель может переносить полученные знания с одних данных на некоторые другие данные, которые она раньше не видела.

# %% [markdown]
# # 1.3 Модель

# %% [markdown]
# Модель в машинном обучении — это программа, которая учится находить закономерности в данных и на их основе делать прогнозы или принимать решения.
#
# На вход она принимает некоторые данные, на выходе дает ответ на какой-либо вопрос (поставленную задачу).

# %% [markdown]
# Задача классификации - логистическая регрессия
#
# Задача регрессии - линейная регрессия

# %% [markdown]
# Решающее дерево
# ![screen_1_1.png](attachment:4a6f0b2a-9b2f-4269-a14d-3d07157cb8b7.png)

# %% [markdown]
# Нейронные сети
#
# Обучим сразу 4 регрессионные модели с разными параметрами. Затем результаты (какие?) преедадим в следующие регрессионные модели. Т.е. построим регрессионные модели, которые друг в друга передают свои предсказания. На выходе получится какая-то магия. Это обсудим позже.
# ![screen_1_2.png](attachment:e821b393-5dc1-479f-a344-9059baa8c0bc.png)

# %% [markdown]
# Обучить модель машинного обучения - это на основании набора данных выявить некие закономерности, которые можно обобщить на новые объекты.
#
# Т.е. обучив модель на 15000 игроках, которые продолжают играть в нашу игру и 15000 игроках, которые покинули игру, а потом для новых игроков, которые попадют в нашу игру и которых модель еще не видела, она сможет их успешно классифицировать.
#
# Таким образом, мы сможем понять собирается ли игрок уходить (на основе каких-то признаков, в которых модель при обучении выявила закономерности, например, время в игре, количество смертей, сумма доната и тд) и применить к таким игрокам соответствующие стратегии/программные решения (рассылки, скидки, интересные подарки в игре и тд.).

# %% [markdown]
# # 1.4 Pandas

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('StudentsPerformance.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ## Атрибуты

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df.groupby('gender').agg({'writing score':'mean'})
# Out:
#         writing score
# gender
# female      72.467181
# male        63.311203

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.size
# Out:
# 8000

# %%
df.empty
# Out:
# False

# %% [markdown]
# ## at и iat

# %%
# синтаксис df.at['метка строки', 'метка столбца']
df.at[0, 'gender']
# Out:
# 'female'

# %%
# df.iat['индекс строки', 'индекс столбца']
df.iat[0, 0]
# Out:
# 'female'

# %% [markdown]
# ## loc и iloc

# %%
# df.iloc['срез индексов строки', 'срез индексов столбца']
df.iloc[0:5, 0:2]
# Out:
#    gender race/ethnicity
# 0  female        group B
# 1  female        group C
# 2  female        group B
# 3    male        group A
# 4    male        group C

# %%
df.loc[0:5, ['gender', 'race/ethnicity']]
# Out:
#    gender race/ethnicity
# 0  female        group B
# 1  female        group C
# 2  female        group B
# 3    male        group A
# 4    male        group C
# 5  female        group B

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
# возвращает датафрейм в виде массива
df.values
# Out:
# array([['female', 'group B', "bachelor's degree", ..., 72, 72, 74],
#        ['female', 'group C', 'some college', ..., 69, 90, 88],
#        ['female', 'group B', "master's degree", ..., 90, 95, 93],
#        ...,
#        ['female', 'group C', 'high school', ..., 59, 71, 65],
#        ['female', 'group D', 'some college', ..., 68, 78, 77],
#        ['female', 'group D', 'some college', ..., 77, 86, 86]],
#       dtype=object)

# %%
df.loc[:6]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
df.iloc[:7, :8]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
df.size
# Out:
# 8000

# %%
df.dtypes.value_counts()
# Out:
# object    5
# int64     3
# Name: count, dtype: int64

# %%
titanic_df = pd.read_csv('~/Desktop/an notebooks/Введение в Data Science и машинное обучение/titanic.csv')

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.shape
# Out:
# (891, 12)

# %%
titanic_df.dtypes.value_counts()
# Out:
# int64      5
# object     5
# float64    2
# Name: count, dtype: int64

# %% [markdown]
# # 1.5 Фильтрация

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.query('gender == "female"')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df[df['gender'] == 'female']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.loc[df['gender'] == 'female']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df['writing score'].mean()
# Out:
# 68.054

# %%
df[df['writing score'] > (df['writing score'].mean())]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df[(df['writing score'] > 99) & (df.gender == 'female')]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 106  female        group D             master's degree      standard
# 114  female        group E           bachelor's degree      standard
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 377  female        group D             master's degree  free/reduced
# 403  female        group D                 high school      standard
# 458  female        group E           bachelor's degree      standard
# 566  female        group E           bachelor's degree  free/reduced
# 685  female        group E             master's degree      standard
# 903  female        group D           bachelor's degree  free/reduced
# 957  female        group D             master's degree      standard
# 962  female        group E          associate's degree      standard
# 970  female        group D           bachelor's degree      standard
#
# ...

# %%
df['lunch'].value_counts(normalize=True)
# Out:
# lunch
# standard        0.645
# free/reduced    0.355
# Name: proportion, dtype: float64

# %%
df.groupby('lunch')[['math score', 'reading score', 'writing score']].agg(['mean', 'var']).round(2)
# Out:
#              math score         reading score         writing score
#                    mean     var          mean     var          mean     var
# lunch
# free/reduced      58.92  229.82         64.65  221.87         63.02  238.20
# standard          70.03  186.42         71.65  191.29         70.82  205.62

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
writing_score = 80

# %%
df.query('writing_score > @writing_score')
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 16     male        group C                 high school      standard
# 34     male        group E                some college      standard
# ..      ...            ...                         ...           ...
# 983  female        group A                some college      standard
# 984  female        group C            some high school      standard
# 989  female        group D                some college  free/reduced
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
df.query(f'writing_score > {writing_score}')
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 16     male        group C                 high school      standard
# 34     male        group E                some college      standard
# ..      ...            ...                         ...           ...
# 983  female        group A                some college      standard
# 984  female        group C            some high school      standard
# 989  female        group D                some college  free/reduced
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
df[df['parental_level_of_education'].isin(["bachelor's degree", "master's degree"])]
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 14   female        group A             master's degree      standard
# 18     male        group C             master's degree  free/reduced
# 24     male        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 957  female        group D             master's degree      standard
# 969  female        group B           bachelor's degree      standard
# 970  female        group D           bachelor's degree      standard
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %% [markdown]
# ## filter

# %%
df.filter(like = 'score')
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %% [markdown]
# # 1.6 Группировка и агрегация

# %%
df.groupby(['gender', 'race/ethnicity'])['writing_score'].nunique()
# Out:
# gender  race/ethnicity
# female  group A           30
#         group B           46
#         group C           53
#         group D           49
#         group E           37
# male    group A           34
#         group B           44
#         group C           53
#         group D           50
#         group E           42
# Name: writing_score, dtype: int64

# %%
dota_df = pd.read_csv('~/Desktop/an notebooks/Введение в Data Science и машинное обучение/dota_hero_stats.csv')

# %%
dota_df.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
dota_df['legs'].value_counts()
# Out:
# legs
# 2    95
# 0    11
# 4     7
# 6     3
# 8     1
# Name: count, dtype: int64

# %%
buh_df = pd.read_csv('~/Desktop/an notebooks/Введение в Data Science и машинное обучение/accountancy.csv')

# %%
buh_df.head()
# Out:
#    Unnamed: 0 Executor Type  Salary
# 0           0     Pupa    D      63
# 1           1     Pupa    A     158
# 2           2     Pupa    D     194
# 3           3     Pupa    E     109
# 4           4    Loopa    E     184

# %%
buh_df.groupby(['Type', 'Executor']).agg({'Salary':'mean'}).sort_values(by=['Type', 'Salary'], ascending=[True, False])
# Out:
#                    Salary
# Type Executor
# A    Pupa      160.833333
#      Loopa      58.000000
# B    Loopa     145.166667
#      Pupa       77.000000
# C    Loopa     154.333333
#      Pupa       74.500000
# D    Pupa      146.500000
#      Loopa     137.714286
# E    Loopa     164.000000
#      Pupa      131.200000
# F    Loopa     238.000000
#      Pupa      136.250000

# %%
dota_df
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
(dota_df.groupby(['attack_type', 'primary_attr'], as_index=False).
 agg({'id':'count'}).
 sort_values(by='id', ascending=False)
)
# Out:
#   attack_type primary_attr  id
# 4      Ranged          int  40
# 2       Melee          str  35
# 0       Melee          agi  19
# 3      Ranged          agi  18
# 5      Ranged          str   3
# 1       Melee          int   2

# %%
algae = pd.read_csv('~/Desktop/an notebooks/Введение в Data Science и машинное обучение/algae.csv')

# %%
algae
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
algae.shape
# Out:
# (10, 8)

# %%
(algae.groupby('genus')
 [['sucrose', 'alanin', 'citrate', 'glucose', 'oleic_acid']].
 mean().
 round(2)
)
# Out:
#              sucrose  alanin  citrate  glucose  oleic_acid
# genus
# Ascophyllum     6.83    0.88     5.25     3.41        2.43
# Cladophora      4.01    4.00     5.29     2.80        2.26
# Fucus           4.36    3.57     4.21     2.81        3.37
# Palmaria        0.70    3.18     5.57     3.24        2.25
# Saccharina      4.18    3.52     3.35     4.98        4.49

# %%
algae.query('genus == "Fucus"')['alanin'].agg(['min', 'mean', 'max']).round(2)
# Out:
# min     0.35
# mean    3.57
# max     6.64
# Name: alanin, dtype: float64

# %%
algae
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
algae.groupby('group')['citrate'].var().round()
# Out:
# group
# brown    5.0
# green    4.0
# red      NaN
# Name: citrate, dtype: float64

# %%
algae.groupby('group')['genus'].count()
# Out:
# group
# brown    6
# green    3
# red      1
# Name: genus, dtype: int64

# %%
t = algae.groupby('group')['sucrose'].agg(['max', 'min'])
t
# Out:
#             max       min
# group
# brown  6.825467  1.636122
# green  5.712284  2.452623
# red    0.704580  0.704580

# %%
t['R'] = t['max'] - t['min']

# %%
t
# Out:
#             max       min         R
# group
# brown  6.825467  1.636122  5.189345
# green  5.712284  2.452623  3.259662
# red    0.704580  0.704580  0.000000

# %% [markdown]
# # Визуализация

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## line

# %%
income_df = pd.read_csv('~/Desktop/an notebooks/Введение в Data Science и машинное обучение/income.csv')

# %%
income_df
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
sns.lineplot(x=income_df.index, y=income_df.income)
# Out:
# <Axes: xlabel='None', ylabel='income'>

# %%
plt.plot(income_df.index, income_df.income)

# %%
sns.lineplot(data=income_df)
# Out:
# <Axes: >

# %% [markdown]
# ## scatter

# %%
df = pd.read_csv('~/Desktop/an notebooks/Введение в Data Science и машинное обучение/dataset_209770_6 (3).txt', sep=' ')

# %%
df.head()
# Out:
#              x            y
# 0    94.675253   503.909400
# 1  1495.968980   598.653038
# 2   396.667549   105.434494
# 3   901.055537  1005.457124
# 4   299.984668  1400.892953

# %%
plt.scatter(x='x', y='y', data=df)

# %% [markdown]
# ## heatmap

# %%
gen = pd.read_csv('~/Desktop/an notebooks/Введение в Data Science и машинное обучение/genome_matrix.csv')

# %%
gen = gen.set_index('Unnamed: 0')
gen
# Out:
#             species0  species1  species2  species3  species4
# Unnamed: 0
# species0    0.536029  0.920292  0.679708  0.840606  0.430842
# species1    0.920292  0.862417  0.887593  0.769754  0.203214
# species2    0.679708  0.887593  0.595156  0.003435  0.096052
# species3    0.840606  0.769754  0.003435  0.458870  0.029251
# species4    0.430842  0.203214  0.096052  0.029251  0.642109

# %%
ax = sns.heatmap(gen, cmap="viridis")
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_tick_params(rotation=0)

# %%
glue = sns.load_dataset("glue")

# %%
glue.pivot(index="Model", columns="Task", values="Score")
# Out:
# Task         CoLA  MNLI  MRPC  QNLI   QQP   RTE  SST-2  STS-B
# Model
# BERT         60.5  86.7  89.3  92.7  72.1  70.1   94.9   87.6
# BiLSTM       11.6  65.6  81.8  74.6  62.5  57.4   82.8   70.3
# BiLSTM+Attn  18.6  67.6  83.9  74.3  60.1  58.4   83.0   72.8
# BiLSTM+CoVe  18.5  65.4  78.7  70.8  60.6  52.7   81.9   64.4
# BiLSTM+ELMo  32.1  67.2  84.7  75.5  61.1  57.4   89.3   70.3
# ERNIE        75.5  92.3  93.9  97.3  75.2  92.6   97.8   93.0
# RoBERTa      67.8  90.8  92.3  95.4  74.3  88.2   96.7   92.2
# T5           71.6  92.2  92.8  96.9  75.1  92.8   97.5   93.1

# %%
glue = sns.load_dataset("glue").pivot(index="Model", columns="Task", values="Score")
sns.heatmap(glue)
# Out:
# <Axes: xlabel='Task', ylabel='Model'>

# %%
dota_df.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles  count_roles
# 0                       ['Carry', 'Escape', 'Nuker']            3
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']            4
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']            4
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...            5
# ...

# %%
dota_df['count_roles'] = dota_df['roles'].str.count(',')+1

# %%
dota_df.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles  count_roles
# 0                       ['Carry', 'Escape', 'Nuker']            3
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']            4
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']            4
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...            5
# ...

# %%
dota_df.groupby('count_roles')['id'].count()
# Out:
# count_roles
# 1     1
# 2     9
# 3    28
# 4    38
# 5    33
# 6     8
# Name: id, dtype: int64

# %% [markdown]
# ## displot - гистограмма распределения

# %%
iris_df = pd.read_csv('~/Desktop/an notebooks/Введение в Data Science и машинное обучение/iris.csv')

# %%
iris_df.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
iris_df.head()
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
for col in iris_df:
    sns.displot(iris_df[col])

# %%
for col in iris_df.columns:
    print(col)
# Out:
# Unnamed: 0
# sepal length
# sepal width
# petal length
# petal width
# species

# %% [markdown]
# ## Violin plot

# %%
sns.violinplot(y=iris_df['petal length'])
# Out:
# <Axes: ylabel='petal length'>

# %% [markdown]
# ## Pairplot

# %% [markdown]
# The simplest invocation uses scatterplot() for each pairing of the variables and histplot() for the marginal plots along the diagonal
#
# pairplot, отражающий зависимость пар переменных друг от друга, а также распределение каждой из переменных.

# %%
iris_df.head()
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
sns.pairplot(iris_df.iloc[:, :-1], kind = 'reg')

# %% [markdown]
# # Практические задания

# %% [markdown]
# ## 1

# %%
my_data=pd.DataFrame(data={'type':['A', 'A', 'B', 'B'],
                             'value':[10, 14, 12, 23]})

# %%
my_data
# Out:
#   type  value
# 0    A     10
# 1    A     14
# 2    B     12
# 3    B     23

# %% [markdown]
# ## 2

# %%
my_stat = pd.read_csv('~/Desktop/an notebooks/Введение в Data Science и машинное обучение/my_stat.csv')

# %%
my_stat.head()
# Out:
#    V1    V2 V3   V4
# 0   2  13.0  B  1.0
# 1  -1   7.0  B  1.0
# 2   0  11.0  A  0.0
# 3   2  11.0  A  2.0
# 4   0  10.0  B -1.0

# %%
my_stat.shape
# Out:
# (500, 4)

# %%
subset_1 = my_stat.iloc[:10, [0, 2]]
subset_1
# Out:
#    V1 V3
# 0   2  B
# 1  -1  B
# 2   0  A
# 3   2  A
# 4   0  B
# 5   2  A
# 6   0  A
# 7   1  A
# 8   0  B
# 9  -1  A

# %%
drop_rows = my_stat.index.isin([0,4])
drop_rows
# Out:
# array([ True, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
subset_2 = my_stat[~drop_rows].iloc[:, [1, 3]]
subset_2
# Out:
#        V2   V4
# 1     7.0  1.0
# 2    11.0  0.0
# 3    11.0  2.0
# 5    11.0  0.0
# 6     9.0  2.0
# ..    ...  ...
# 495   8.0 -1.0
# 496   8.0  1.0
# 497  11.0  2.0
# 498  11.0  2.0
# 499   8.0  1.0
#
# [498 rows x 2 columns]

# %% [markdown]
# ## 3

# %% [markdown]
# В переменную subset_1 сохраните только те наблюдения, у которых значения переменной V1  строго больше 0, и значение переменной V3  равняется 'A'.

# %%
subset_1 = my_stat.query("(V1 > 0) & (V3 =='A')")

# %% [markdown]
# В переменную  subset_2  сохраните только те наблюдения, у которых значения переменной V2  не равняются 10, или значения переменной V4 больше или равно 1.

# %%
subset_2 = my_stat.query("(V2 != 10) | (V4 >=1)")

# %% [markdown]
# ## 4

# %% [markdown]
# В этих данных (my_stat) создайте две новые переменных:
#
# V5 = V1 + V4
#
# V6 = натуральный логарифм переменной V2

# %%
my_stat['V5'] = my_stat['V1'] + my_stat['V4']

# %%
my_stat['V6'] = np.log(my_stat['V2'])

# %% [markdown]
# ## 5

# %% [markdown]
# Переименуйте колонки в данных  my_stat следующим образом:
#
# V1 -> session_value
#
# V2 -> group
#
# V3 -> time
#
# V4 -> n_users

# %%
my_stat = my_stat.rename(columns={'V1':'session_value', 
                                  'V2':'group',
                                  'V3':'time',
                                  'V4':'n_users'})

# %%
my_stat.head()
# Out:
#    session_value  group time  n_users   V5        V6
# 0              2   13.0    B      1.0  3.0  2.564949
# 1             -1    7.0    B      1.0  0.0  1.945910
# 2              0   11.0    A      0.0  0.0  2.397895
# 3              2   11.0    A      2.0  4.0  2.397895
# 4              0   10.0    B     -1.0 -1.0  2.302585

# %% [markdown]
# ## 6 - Замена значений по условию

# %% [markdown]
# В переменной session_value замените все пропущенные значения на нули.
#
# В переменной n_users замените все отрицательные значения на медианное значение переменной n_users (без учета отрицательных значений, разумеется).

# %%
my_stat_1 = pd.read_csv('~/Desktop/an notebooks/Введение в Data Science и машинное обучение/my_stat_1.csv')

# %%
my_stat_1['session_value'] = my_stat_1['session_value'].fillna(0)

# %%
med = my_stat_1[my_stat_1['n_users'] >= 0]['n_users'].median()
med
# Out:
# 5.0

# %%
# Replace col1 values with col2 values if col1 == 'same'
my_stat_1.loc[my_stat_1['n_users'] < 0, 'n_users'] = med

# %%
my_stat_1
# Out:
#    session_value  time group  n_users
# 0              2    12     B        9
# 1             -1    11     A        5
# 2              0     8     A        1
# 3              2     9     B        3
# 4              0    10     B        9
# 5              2     8     A        8
# 6              0    11     B        5
# 7              1     9     A        4
# 8              0     8     B        5
# 9             -1     9     A        5

# %%
my_stat_1 = pd.read_csv('~/Desktop/an notebooks/Введение в Data Science и машинное обучение/my_stat.csv')

# %%
my_stat_1 = my_stat_1.rename(columns={'V1':'session_value', 
                                  'V2':'group',
                                  'V3':'time',
                                  'V4':'n_users'})

# %% [markdown]
# в loc можно передавать условие. Просто вот пандас пишет, что используй лок, а через обычную фильтрацию выдает ошибку

# %%
my_stat_1
# Out:
#      session_value  group time  n_users
# 0                2   13.0    B      1.0
# 1               -1    7.0    B      1.0
# 2                0   11.0    A      0.0
# 3                2   11.0    A      2.0
# 4                0   10.0    B     -1.0
# ..             ...    ...  ...      ...
# 495              1    8.0    A     -1.0
# 496              3    8.0    A      1.0
# 497             -1   11.0    B      2.0
# 498              1   11.0    A      2.0
# 499              0    8.0    B      1.0
#
# [500 rows x 4 columns]

# %%
my_stat_1.loc[my_stat_1['n_users'] < 0, 'n_users']
# Out:
# 4     -1.0
# 31    -1.0
# 59    -1.0
# 86    -1.0
# 104   -1.0
# 106   -2.0
# 119   -1.0
# 122   -1.0
# 131   -1.0
# 162   -1.0
# 165   -1.0
# 220   -1.0
# 244   -1.0
# 245   -1.0
# 248   -1.0
# 304   -1.0
# 312   -1.0
# 314   -1.0
# 367   -1.0
# 391   -1.0
# 495   -1.0
# Name: n_users, dtype: float64

# %%
my_stat[my_stat['n_users'] < 0]['n_users'] = med
# Out:
# C:\Users\ryagu\AppData\Local\Temp\ipykernel_11076\1883993725.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   my_stat[my_stat['n_users'] < 0]['n_users'] = med

# %% [markdown]
# ## 7

# %% [markdown]
# В этой задаче для данных my_stat рассчитайте среднее значение переменной session_value для каждой группы (переменная group), в получившемся dataframe  переменная group не должна превратиться в индекс. Также переименуйте колонку со средним значением session_value в mean_session_value.
#
# Получившийся результат сохраните в dataframe с именем mean_session_value_data.

# %%
my_stat.head()
# Out:
#    session_value  group time  n_users
# 0              2   13.0    B      1.0
# 1             -1    7.0    B      1.0
# 2              0   11.0    A      0.0
# 3              2   11.0    A      2.0
# 4              0   10.0    B     -1.0

# %%
mean_session_value_data = (my_stat.
                           groupby('group', as_index=False)
                           ['session_value'].
                           mean().
                           rename(columns={'session_value':'mean_session_value'}))

# %%
mean_session_value_data
# Out:
#    group  mean_session_value
# 0    5.0            0.000000
# 1    7.0            0.333333
# 2    8.0            0.633333
# 3    9.0            0.238938
# 4   10.0            0.065990
# 5   11.0           -0.081081
# 6   12.0           -0.078947
# 7   13.0            0.000000
